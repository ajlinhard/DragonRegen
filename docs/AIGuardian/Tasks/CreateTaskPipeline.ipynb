# %%
import os
import sys
import json

notebook_path = os.getcwd()
project_path = os.path.abspath(os.path.join(notebook_path, '..','..','..'))
print(f"Project path: {project_path}")
# Add the project path to sys.path
sys.path.append(project_path)
# Out:
# Project path: c:\Users\dalej\Documents\_Coding\DragonRegen

# %%
from src.AIGuardian.Tasks.DataStructCreate import DataStructCreate
from src.MetaFort.SysLogs.KafkaEngine import KafkaEngine
from src.MetaFort.AILoggingTopics import AILoggingTopics

subset_objects = [AILoggingTopics.AI_TASK_COMPLETED_TOPIC]

start_action = DataStructCreate()
start_action.db_engine = KafkaEngine.default_builder(subset_objects)

prompt = """Create a set of tables for a simple online car insurance quoting engine."""
start_action.run(prompt)
# Out:
# ==> Running DataStructCreate with prompt: Create a set of tables for a simple online car insurance quoting engine.
# ==> Task 7ed334d5-e6a2-4a17-bca9-6ff153de8584 complete_task

# %%
print(start_action.output_params.keys())
print(json.dumps(start_action.output_params, indent=2))
# Out:
# dict_keys(['users', 'addresses', 'vehicles', 'drivers', 'driver_history', 'coverage_types', 'quote_requests', 'quotes', 'quote_coverages', 'discount_types', 'quote_discounts'])
# {
#   "users": {
#     "purpose": "Stores information about registered users who request car insurance quotes",
#     "fields": {
#       "user_id": "unique ID, primary key for user identification",
#       "first_name": "user's first name",
#       "last_name": "user's last name",
#       "email": "user's email address for communication",
#       "phone_number": "user's contact phone number",
#       "date_of_birth": "user's date of birth for age calculation",
#       "address_id": "foreign key to addresses table",
#       "created_at": "timestamp when user record was created",
#       "updated_at": "timestamp when user record was last updated"
#     }
#   },
#   "addresses": {
#     "purpose": "Stores address information for users and risk assessment",
#     "fields": {
#       "address_id": "unique ID, primary key for address identification",
#       "street_address": "street number and name",
#       "city": "city name",
#       "state": "state or province",
#       "zip_code": "postal code",
#       "country": "country name"
#     }
#   },
#   "vehicles": {
#     "purpose": "Stores information about vehicles to be insured",
#     "fields": {
#       "vehicle_id": "unique ID, primary key for vehicle identification",
#       "user_id": "foreign key to users table",
#       "make": "vehicle manufacturer",
#       "model": "vehicle model name",
#       "year": "year of manufacture",
#       "vin": "vehicle identification number",
#       "primary_use": "primary use of vehicle (commute, pleasure, business)",
#       "annual_mileage": "estimated annual mileage",
#       "garage_address_id": "foreign key to addresses table for where vehicle is kept"
#     }
#   },
#   "drivers": {
#     "purpose": "Stores information about drivers to be covered by the insurance",
#     "fields": {
#       "driver_id": "unique ID, primary key for driver identification",
#       "user_id": "foreign key to users table",
#       "license_number": "driver's license number",
#       "license_state": "state where license was issued",
#       "years_licensed": "number of years driver has been licensed",
#       "is_primary": "boolean indicating if this is the primary driver"
#     }
#   },
#   "driver_history": {
#     "purpose": "Stores driving history information for risk assessment",
#     "fields": {
#       "history_id": "unique ID, primary key for history record",
#       "driver_id": "foreign key to drivers table",
#       "incident_type": "type of incident (accident, violation, claim)",
#       "incident_date": "date when incident occurred",
#       "description": "description of the incident",
#       "at_fault": "boolean indicating if driver was at fault (for accidents)"
#     }
#   },
#   "coverage_types": {
#     "purpose": "Stores different types of insurance coverage available",
#     "fields": {
#       "coverage_id": "unique ID, primary key for coverage type",
#       "name": "name of coverage (liability, comprehensive, collision, etc.)",
#       "description": "detailed description of what the coverage includes",
#       "is_required": "boolean indicating if coverage is legally required"
#     }
#   },
#   "quote_requests": {
#     "purpose": "Stores information about quote requests initiated by users",
#     "fields": {
#       "quote_request_id": "unique ID, primary key for quote request",
#       "user_id": "foreign key to users table",
#       "request_date": "timestamp when quote was requested",
#       "status": "current status of quote request (pending, completed, expired)",
#       "effective_date": "requested start date for insurance coverage"
#     }
#   },
#   "quotes": {
#     "purpose": "Stores generated insurance quotes with pricing information",
#     "fields": {
#       "quote_id": "unique ID, primary key for quote",
#       "quote_request_id": "foreign key to quote_requests table",
#       "total_premium": "total cost of insurance premium",
#       "payment_frequency": "frequency of payments (monthly, quarterly, annually)",
#       "created_at": "timestamp when quote was generated",
#       "expires_at": "timestamp when quote expires",
#       "is_accepted": "boolean indicating if quote was accepted by user"
#     }
#   },
#   "quote_coverages": {
#     "purpose": "Junction table linking quotes to selected coverage types with specific limits and deductibles",
#     "fields": {
#       "quote_coverage_id": "unique ID, primary key for quote coverage relationship",
#       "quote_id": "foreign key to quotes table",
#       "coverage_id": "foreign key to coverage_types table",
#       "coverage_limit": "maximum amount insurance will pay for this coverage",
#       "deductible": "amount insured must pay before insurance covers the rest",
#       "premium_amount": "cost for this specific coverage"
#     }
#   },
#   "discount_types": {
#     "purpose": "Stores different types of discounts available for insurance quotes",
#     "fields": {
#       "discount_id": "unique ID, primary key for discount type",
#       "name": "name of discount (safe driver, multi-policy, etc.)",
#       "description": "detailed description of the discount",
#       "percentage": "standard percentage amount for this discount type"
#     }
#   },
#   "quote_discounts": {
#     "purpose": "Junction table linking quotes to applied discounts",
#     "fields": {
#       "quote_discount_id": "unique ID, primary key for quote discount relationship",
#       "quote_id": "foreign key to quotes table",
#       "discount_id": "foreign key to discount_types table",
#       "applied_percentage": "actual percentage applied for this specific quote",
#       "amount": "monetary value of the discount"
#     }
#   }
# }

# %%
# Run the Scheme Refiner
from src.AIGuardian.Tasks.SchemaRefiner import SchemaRefiner

test_schema_refiner = SchemaRefiner(input_params=start_action.output_params, parent_task=start_action)
test_schema_refiner.db_engine = KafkaEngine.default_builder(subset_objects)
print(test_schema_refiner)
# Out:
# <src.AIGuardian.Tasks.SchemaRefiner.SchemaRefiner object at 0x0000018446E23410>

# %%
print(test_schema_refiner.input_params)
print(start_action.output_params)
# Out:
# {'users': {'purpose': 'Stores information about registered users who request car insurance quotes', 'fields': {'user_id': 'unique ID, primary key for user identification', 'first_name': "user's first name", 'last_name': "user's last name", 'email': "user's email address for communication", 'phone_number': "user's contact phone number", 'date_of_birth': "user's date of birth for age calculation", 'address_id': 'foreign key to addresses table', 'created_at': 'timestamp when user record was created', 'updated_at': 'timestamp when user record was last updated'}}, 'addresses': {'purpose': 'Stores address information for users and risk assessment', 'fields': {'address_id': 'unique ID, primary key for address identification', 'street_address': 'street number and name', 'city': 'city name', 'state': 'state or province', 'zip_code': 'postal code', 'country': 'country name'}}, 'vehicles': {'purpose': 'Stores information about vehicles to be insured', 'fields': {'vehicle_id': 'unique ID, primary key for vehicle identification', 'user_id': 'foreign key to users table', 'make': 'vehicle manufacturer', 'model': 'vehicle model name', 'year': 'year of manufacture', 'vin': 'vehicle identification number', 'primary_use': 'primary use of vehicle (commute, pleasure, business)', 'annual_mileage': 'estimated annual mileage', 'garage_address_id': 'foreign key to addresses table for where vehicle is kept'}}, 'drivers': {'purpose': 'Stores information about drivers to be covered by the insurance', 'fields': {'driver_id': 'unique ID, primary key for driver identification', 'user_id': 'foreign key to users table', 'license_number': "driver's license number", 'license_state': 'state where license was issued', 'years_licensed': 'number of years driver has been licensed', 'is_primary': 'boolean indicating if this is the primary driver'}}, 'driver_history': {'purpose': 'Stores driving history information for risk assessment', 'fields': {'history_id': 'unique ID, primary key for history record', 'driver_id': 'foreign key to drivers table', 'incident_type': 'type of incident (accident, violation, claim)', 'incident_date': 'date when incident occurred', 'description': 'description of the incident', 'at_fault': 'boolean indicating if driver was at fault (for accidents)'}}, 'coverage_types': {'purpose': 'Stores different types of insurance coverage available', 'fields': {'coverage_id': 'unique ID, primary key for coverage type', 'name': 'name of coverage (liability, comprehensive, collision, etc.)', 'description': 'detailed description of what the coverage includes', 'is_required': 'boolean indicating if coverage is legally required'}}, 'quote_requests': {'purpose': 'Stores information about quote requests initiated by users', 'fields': {'quote_request_id': 'unique ID, primary key for quote request', 'user_id': 'foreign key to users table', 'request_date': 'timestamp when quote was requested', 'status': 'current status of quote request (pending, completed, expired)', 'effective_date': 'requested start date for insurance coverage'}}, 'quotes': {'purpose': 'Stores generated insurance quotes with pricing information', 'fields': {'quote_id': 'unique ID, primary key for quote', 'quote_request_id': 'foreign key to quote_requests table', 'total_premium': 'total cost of insurance premium', 'payment_frequency': 'frequency of payments (monthly, quarterly, annually)', 'created_at': 'timestamp when quote was generated', 'expires_at': 'timestamp when quote expires', 'is_accepted': 'boolean indicating if quote was accepted by user'}}, 'quote_coverages': {'purpose': 'Junction table linking quotes to selected coverage types with specific limits and deductibles', 'fields': {'quote_coverage_id': 'unique ID, primary key for quote coverage relationship', 'quote_id': 'foreign key to quotes table', 'coverage_id': 'foreign key to coverage_types table', 'coverage_limit': 'maximum amount insurance will pay for this coverage', 'deductible': 'amount insured must pay before insurance cover ...
# {'users': {'purpose': 'Stores information about registered users who request car insurance quotes', 'fields': {'user_id': 'unique ID, primary key for user identification', 'first_name': "user's first name", 'last_name': "user's last name", 'email': "user's email address for communication", 'phone_number': "user's contact phone number", 'date_of_birth': "user's date of birth for age calculation", 'address_id': 'foreign key to addresses table', 'created_at': 'timestamp when user record was created', 'updated_at': 'timestamp when user record was last updated'}}, 'addresses': {'purpose': 'Stores address information for users and risk assessment', 'fields': {'address_id': 'unique ID, primary key for address identification', 'street_address': 'street number and name', 'city': 'city name', 'state': 'state or province', 'zip_code': 'postal code', 'country': 'country name'}}, 'vehicles': {'purpose': 'Stores information about vehicles to be insured', 'fields': {'vehicle_id': 'unique ID, primary key for vehicle identification', 'user_id': 'foreign key to users table', 'make': 'vehicle manufacturer', 'model': 'vehicle model name', 'year': 'year of manufacture', 'vin': 'vehicle identification number', 'primary_use': 'primary use of vehicle (commute, pleasure, business)', 'annual_mileage': 'estimated annual mileage', 'garage_address_id': 'foreign key to addresses table for where vehicle is kept'}}, 'drivers': {'purpose': 'Stores information about drivers to be covered by the insurance', 'fields': {'driver_id': 'unique ID, primary key for driver identification', 'user_id': 'foreign key to users table', 'license_number': "driver's license number", 'license_state': 'state where license was issued', 'years_licensed': 'number of years driver has been licensed', 'is_primary': 'boolean indicating if this is the primary driver'}}, 'driver_history': {'purpose': 'Stores driving history information for risk assessment', 'fields': {'history_id': 'unique ID, primary key for history record', 'driver_id': 'foreign key to drivers table', 'incident_type': 'type of incident (accident, violation, claim)', 'incident_date': 'date when incident occurred', 'description': 'description of the incident', 'at_fault': 'boolean indicating if driver was at fault (for accidents)'}}, 'coverage_types': {'purpose': 'Stores different types of insurance coverage available', 'fields': {'coverage_id': 'unique ID, primary key for coverage type', 'name': 'name of coverage (liability, comprehensive, collision, etc.)', 'description': 'detailed description of what the coverage includes', 'is_required': 'boolean indicating if coverage is legally required'}}, 'quote_requests': {'purpose': 'Stores information about quote requests initiated by users', 'fields': {'quote_request_id': 'unique ID, primary key for quote request', 'user_id': 'foreign key to users table', 'request_date': 'timestamp when quote was requested', 'status': 'current status of quote request (pending, completed, expired)', 'effective_date': 'requested start date for insurance coverage'}}, 'quotes': {'purpose': 'Stores generated insurance quotes with pricing information', 'fields': {'quote_id': 'unique ID, primary key for quote', 'quote_request_id': 'foreign key to quote_requests table', 'total_premium': 'total cost of insurance premium', 'payment_frequency': 'frequency of payments (monthly, quarterly, annually)', 'created_at': 'timestamp when quote was generated', 'expires_at': 'timestamp when quote expires', 'is_accepted': 'boolean indicating if quote was accepted by user'}}, 'quote_coverages': {'purpose': 'Junction table linking quotes to selected coverage types with specific limits and deductibles', 'fields': {'quote_coverage_id': 'unique ID, primary key for quote coverage relationship', 'quote_id': 'foreign key to quotes table', 'coverage_id': 'foreign key to coverage_types table', 'coverage_limit': 'maximum amount insurance will pay for this coverage', 'deductible': 'amount insured must pay before insurance cover ...

# %%
test_schema_refiner.run(prompt)
# Out:
# ==> Waiting on ['9bc9153d-d1bf-4378-b5ee-45add23c2bb2', '3dd9606c-f32d-4be4-b8eb-2a4db6dcedbe', 'e94f755c-46ec-4803-ab37-ab3c5e98b56b', '511ed904-7f66-44ed-ada3-edd4814169bd', 'ce83b064-af44-49c6-a0ff-00d0fb8f455a', '5db51243-4d05-4bee-9a03-5735f261fb66', '2567a854-107c-4240-bc7e-282a879d75a8', '5499429c-3dab-4f8b-baae-bedc82745cb5', 'b606cfc4-aa90-4cb9-8aac-b8d6be3b5a90', '5b31fd3d-6979-454d-8a15-eca024d9b5bc', 'c3420bd2-380d-413c-9d21-66219ec34406'] to complete.
# ==> Removing 9bc9153d-d1bf-4378-b5ee-45add23c2bb2 from child tasks.
# ==> Removing 5db51243-4d05-4bee-9a03-5735f261fb66 from child tasks.
# ==> Removing 5b31fd3d-6979-454d-8a15-eca024d9b5bc from child tasks.
# ==> Removing 3dd9606c-f32d-4be4-b8eb-2a4db6dcedbe from child tasks.
# ==> Task 1ebae1d8-38e2-4266-b4a6-0fb5795a85e0 complete_task

# %%
while test_schema_refiner.is_waiting():
    print("Waiting for the schema refiner to finish...")
    test_schema_refiner.wait_on_dependency()
# Out:
# Waiting for the schema refiner to finish...
# ==> Waiting on ['e94f755c-46ec-4803-ab37-ab3c5e98b56b', '511ed904-7f66-44ed-ada3-edd4814169bd', 'ce83b064-af44-49c6-a0ff-00d0fb8f455a', '2567a854-107c-4240-bc7e-282a879d75a8', '5499429c-3dab-4f8b-baae-bedc82745cb5', 'b606cfc4-aa90-4cb9-8aac-b8d6be3b5a90', 'c3420bd2-380d-413c-9d21-66219ec34406'] to complete.
# ==> Removing 2567a854-107c-4240-bc7e-282a879d75a8 from child tasks.
# ==> Removing 511ed904-7f66-44ed-ada3-edd4814169bd from child tasks.
# ==> Removing c3420bd2-380d-413c-9d21-66219ec34406 from child tasks.
# Waiting for the schema refiner to finish...
# ==> Waiting on ['e94f755c-46ec-4803-ab37-ab3c5e98b56b', 'ce83b064-af44-49c6-a0ff-00d0fb8f455a', '5499429c-3dab-4f8b-baae-bedc82745cb5', 'b606cfc4-aa90-4cb9-8aac-b8d6be3b5a90'] to complete.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 while test_schema_refiner.is_waiting():
#       2     print("Waiting for the schema refiner to finish...")
# ----> 3     test_schema_refiner.wait_on_dependency()
#
# File c:\Users\dalej\Documents\_Coding\DragonRegen\src\AIGuardian\Tasks\Task.py:176, in Task.record_step.<locals>.record_decorator.<locals>.wrapper(self, *args, **kwargs)
#     173 self.update_task(task_state=task_state, step_status=f'{func_name} - PROCESSING')
#     174 try:
#     175     # Call the original function
# --> 176     result = func(self, *args, **kwargs)
#     177     # Log the end of the step
#     178     self.update_task(task_state=task_state, step_status=f'{func_name} - SUCCESS')
#
# File c:\Users\dalej\Documents\_Coding\DragonRegen\src\AIGuardian\Tasks\TaskGenerator.py:100, in TaskGenerator.wait_on_dependency(self, timeout)
#      95 @Task.record_step(TaskState.input_required)
#      96 def wait_on_dependency(self, timeout=180):
#      97     """
#      98     Wait for the Task to complete before proceeding.
#      99     """
# --> 100     super().wait_on_dependency(timeout=timeout)
#
# File c:\Users\dalej\Documents\_Coding\DragonRegen\src\AIGuardian\Tasks\Task.py:176, in Task.record_step.<locals>.record_decorator.<locals>.wrapper(self, *args, **kwargs)
#     173 self.update_task(task_state=task_state, step_status=f'{func_name} - PROCESSING')
#     174 try:
#     175     # Call the original function
# --> 176     result = func(self, *args, **kwargs)
#     177     # Log the end of the step
#     178     self.update_task(task_state=task_state, step_status=f'{func_name} - SUCCESS')
#
# File c:\Users\dalej\Documents\_Coding\DragonRegen\src\AIGuardian\Tasks\Task.py:340, in Task.wait_on_dependency(self, timeout)
#     338 print(f"==> Waiting on {self.child_task} to complete.")
#     339 while self.child_task and (datetime.datetime.now() - start_time).total_seconds() < timeout:
# --> 340     completed_tasks = self.db_engine.consumers[AILoggingTopics.AI_TASK_COMPLETED_TOPIC].poll(timeout_ms=1000, max_records=10)
#     341     self.wait_on_dependency_check(completed_tasks)
#
# File f:\Python\envs\Kafka_Spark\Lib\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File f:\Python\envs\Kafka_Spark\Lib\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File f:\Python\envs\Kafka_Spark\Lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File f:\Python\envs\Kafka_Spark\Lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File f:\Python\envs\Kafka_Spark\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File f:\Python\envs\Kafka_Spark\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:

# %%
print(test_schema_refiner.input_params.keys())
print(test_schema_refiner.output_params.keys())
print(json.dumps(test_schema_refiner.output_params, indent=2))
# Out:
# dict_keys(['customers', 'vehicles', 'drivers', 'driving_history', 'coverage_options', 'quotes', 'quote_coverages', 'discount_types', 'quote_discounts'])
# dict_keys(['customers', 'vehicles', 'drivers', 'driving_history', 'coverage_options', 'quotes', 'quote_coverages', 'discount_types', 'quote_discounts'])
# {
#   "customers": {
#     "purpose": "Stores information about customers who request car insurance quotes",
#     "fields": [
#       {
#         "name": "customer_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "unique ID, primary key for customer identification",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "first_name",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "customer's first name",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "StringFirstName"
#         }
#       },
#       {
#         "name": "last_name",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "customer's last name",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "StringLastName"
#         }
#       },
#       {
#         "name": "email",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "customer's email address for communication",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Email"
#         }
#       },
#       {
#         "name": "phone_number",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "customer's contact phone number",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "StringBasic"
#         }
#       },
#       {
#         "name": "date_of_birth",
#         "type": "Date",
#         "nullable": false,
#         "metadata": {
#           "description": "customer's date of birth for age calculation",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "address_line_1",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "first line of customer's address",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Text"
#         }
#       },
#       {
#         "name": "address_line_2",
#         "type": "String",
#         "nullable": true,
#         "metadata": {
#           "description": "second line of customer's address (optional)",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Text"
#         }
#       },
#       {
#         "name": "city",
#         "type": "String",
#         "nullable": true,
#         "metadata": {
#           "description": "customer's city of residence",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "City"
#         }
#       },
#       {
#         "name": "state",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "Customer's state of residence, representing the U.S. state where the customer requesting car insurance quotes lives.",
#           "unique_fl": false,
#           "column_values": [
#             "AL",
#             "AK",
#             "AZ",
#             "AR",
#             "CA",
#             "CO",
#             "CT",
#             "DE",
#             "FL",
#             "GA",
#             "HI",
#             "ID",
#             "IL",
#             "IN",
#             "IA",
#             "KS",
#             "KY",
#             "LA",
#             "ME",
#             "MD",
#             "MA",
#             "MI",
#             "MN",
#             "MS",
#             "MO",
#             "MT",
#             "NE",
#             "NV",
#             "NH",
#             "NJ",
#             "NM",
#             "NY",
#             "NC",
#             "ND",
#             "OH",
#             "OK",
#             "OR",
#             "PA",
#             "RI",
#             "SC",
#             "SD",
#             "TN",
#             "TX",
#             "UT",
#             "VT",
#             "VA",
#             "WA",
#             "WV",
#             "WI",
#             "WY",
#             "DC"
#           ],
#           "col_type": "Categorical"
#         }
#       },
#       {
#         "name": "zip_code",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "Customer's postal code used for location-based insurance quote calculations and regional risk assessment.",
#           "unique_fl": "False",
#           "column_values": [
#             "10001",
#             "90210",
#             "60601",
#             "02108",
#             "33101"
#           ],
#           "col_type": "Categorical"
#         }
#       },
#       {
#         "name": "created_at",
#         "type": "Timestamp",
#         "nullable": false,
#         "metadata": {
#           "description": "timestamp when customer record was created",
#           "unique_fl": false,
#           "default_value": "CURRENT_TIMESTAMP",
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "updated_at",
#         "type": "Timestamp",
#         "nullable": true,
#         "metadata": {
#           "description": "timestamp when customer record was last updated",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       }
#     ]
#   },
#   "vehicles": {
#     "purpose": "Stores information about vehicles to be insured",
#     "fields": [
#       {
#         "name": "vehicle_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "unique ID, primary key for vehicle identification",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "customer_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "foreign key referencing customers table",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "make",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "Manufacturer of the vehicle to be insured. Identifies the company that produced the vehicle.",
#           "unique_fl": "False",
#           "column_values": [
#             "Toyota",
#             "Honda",
#             "Ford",
#             "Chevrolet",
#             "BMW",
#             "Mercedes-Benz",
#             "Audi",
#             "Nissan",
#             "Hyundai",
#             "Kia"
#           ],
#           "col_type": "Categorical"
#         }
#       },
#       {
#         "name": "model",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "Model name of the vehicle to be insured. Represents the specific model designation of the vehicle.",
#           "unique_fl": "False",
#           "column_values": [
#             "Civic",
#             "Accord",
#             "Camry",
#             "Corolla",
#             "F-150",
#             "Silverado",
#             "CR-V",
#             "RAV4",
#             "Mustang",
#             "Explorer"
#           ],
#           "col_type": "Categorical"
#         }
#       },
#       {
#         "name": "year",
#         "type": "Integer",
#         "nullable": true,
#         "metadata": {
#           "description": "year the vehicle was manufactured",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Integer"
#         }
#       },
#       {
#         "name": "vin",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "vehicle identification number",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "mileage",
#         "type": "Integer",
#         "nullable": true,
#         "metadata": {
#           "description": "current mileage of the vehicle",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Integer"
#         }
#       },
#       {
#         "name": "primary_use",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "Primary use of vehicle, indicating how the vehicle is primarily used by the insured party.",
#           "unique_fl": false,
#           "column_values": [
#             "commute",
#             "pleasure",
#             "business"
#           ],
#           "col_type": "Categorical"
#         }
#       },
#       {
#         "name": "ownership_status",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "Indicates whether the insured vehicle is owned, leased, or financed by the policyholder.",
#           "unique_fl": false,
#           "column_values": [
#             "owned",
#             "leased",
#             "financed"
#           ],
#           "col_type": "Categorical"
#         }
#       },
#       {
#         "name": "created_at",
#         "type": "Timestamp",
#         "nullable": false,
#         "metadata": {
#           "description": "timestamp when vehicle record was created",
#           "unique_fl": false,
#           "default_value": "CURRENT_TIMESTAMP",
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "updated_at",
#         "type": "Timestamp",
#         "nullable": true,
#         "metadata": {
#           "description": "timestamp when vehicle record was last updated",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       }
#     ]
#   },
#   "drivers": {
#     "purpose": "Stores information about drivers to be covered by the insurance",
#     "fields": [
#       {
#         "name": "driver_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "unique ID, primary key for driver identification",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "customer_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "Foreign key referencing customers table",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "first_name",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "driver's first name",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "StringFirstName"
#         }
#       },
#       {
#         "name": "last_name",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "driver's last name",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "StringLastName"
#         }
#       },
#       {
#         "name": "license_number",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "driver's license number",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "license_state",
#         "type": "String",
#         "nullable": true,
#         "metadata": {
#           "description": "State where driver's license was issued. Identifies the U.S. state that issued the driver's license for insurance coverage purposes.",
#           "unique_fl": "False",
#           "column_values": [
#             "AL",
#             "AK",
#             "AZ",
#             "AR",
#             "CA",
#             "CO",
#             "CT",
#             "DE",
#             "FL",
#             "GA",
#             "HI",
#             "ID",
#             "IL",
#             "IN",
#             "IA",
#             "KS",
#             "KY",
#             "LA",
#             "ME",
#             "MD",
#             "MA",
#             "MI",
#             "MN",
#             "MS",
#             "MO",
#             "MT",
#             "NE",
#             "NV",
#             "NH",
#             "NJ",
#             "NM",
#             "NY",
#             "NC",
#             "ND",
#             "OH",
#             "OK",
#             "OR",
#             "PA",
#             "RI",
#             "SC",
#             "SD",
#             "TN",
#             "TX",
#             "UT",
#             "VT",
#             "VA",
#             "WA",
#             "WV",
#             "WI",
#             "WY",
#             "DC"
#           ],
#           "col_type": "Categorical"
#         }
#       },
#       {
#         "name": "date_of_birth",
#         "type": "Date",
#         "nullable": false,
#         "metadata": {
#           "description": "driver's date of birth",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "marital_status",
#         "type": "String",
#         "nullable": true,
#         "metadata": {
#           "description": "Driver's marital status, indicating whether the insured driver is single, married, divorced, widowed, etc.",
#           "unique_fl": false,
#           "column_values": [
#             "Single",
#             "Married",
#             "Divorced",
#             "Widowed",
#             "Separated",
#             "Domestic Partnership"
#           ],
#           "col_type": "Categorical"
#         }
#       },
#       {
#         "name": "years_licensed",
#         "type": "Integer",
#         "nullable": true,
#         "metadata": {
#           "description": "number of years driver has been licensed",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Integer"
#         }
#       },
#       {
#         "name": "created_at",
#         "type": "Timestamp",
#         "nullable": false,
#         "metadata": {
#           "description": "timestamp when driver record was created",
#           "unique_fl": false,
#           "default_value": "CURRENT_TIMESTAMP",
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "updated_at",
#         "type": "Timestamp",
#         "nullable": true,
#         "metadata": {
#           "description": "timestamp when driver record was last updated",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       }
#     ]
#   },
#   "driving_history": {
#     "purpose": "Stores information about driving incidents for each driver",
#     "fields": [
#       {
#         "name": "history_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "unique ID, primary key for driving history record",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "driver_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "foreign key referencing drivers table",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "incident_type",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "Type of driving incident that occurred, categorized as accident, violation, or claim.",
#           "unique_fl": false,
#           "column_values": [
#             "accident",
#             "violation",
#             "claim"
#           ],
#           "col_type": "Categorical"
#         }
#       },
#       {
#         "name": "incident_date",
#         "type": "Date",
#         "nullable": false,
#         "metadata": {
#           "description": "date when the incident occurred",
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "description",
#         "type": "String",
#         "nullable": true,
#         "metadata": {
#           "description": "description of the incident",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Text"
#         }
#       },
#       {
#         "name": "at_fault",
#         "type": "Boolean",
#         "nullable": true,
#         "metadata": {
#           "description": "boolean indicating if driver was at fault (for accidents)",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Boolean"
#         }
#       },
#       {
#         "name": "created_at",
#         "type": "Timestamp",
#         "nullable": false,
#         "metadata": {
#           "description": "timestamp when history record was created",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "updated_at",
#         "type": "Timestamp",
#         "nullable": true,
#         "metadata": {
#           "description": "timestamp when history record was last updated",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       }
#     ]
#   },
#   "coverage_options": {
#     "purpose": "Stores available insurance coverage options",
#     "fields": [
#       {
#         "name": "coverage_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "unique ID, primary key for coverage identification",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "coverage_type",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "Type of insurance coverage offered, such as liability, collision, comprehensive, etc.",
#           "unique_fl": "True",
#           "column_values": [
#             "liability",
#             "collision",
#             "comprehensive",
#             "uninsured motorist",
#             "personal injury protection",
#             "medical payments",
#             "gap insurance",
#             "rental reimbursement",
#             "roadside assistance"
#           ],
#           "col_type": "Categorical"
#         }
#       },
#       {
#         "name": "description",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "detailed description of the coverage",
#           "col_type": "Text"
#         }
#       },
#       {
#         "name": "is_active",
#         "type": "Boolean",
#         "nullable": false,
#         "metadata": {
#           "description": "boolean indicating if this coverage option is currently offered",
#           "unique_fl": false,
#           "default_value": true,
#           "col_type": "Boolean"
#         }
#       },
#       {
#         "name": "created_at",
#         "type": "Timestamp",
#         "nullable": false,
#         "metadata": {
#           "description": "timestamp when coverage option was created",
#           "unique_fl": false,
#           "default_value": "CURRENT_TIMESTAMP",
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "updated_at",
#         "type": "Timestamp",
#         "nullable": false,
#         "metadata": {
#           "description": "timestamp when coverage option was last updated",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       }
#     ]
#   },
#   "quotes": {
#     "purpose": "Stores insurance quotes generated for customers",
#     "fields": [
#       {
#         "name": "quote_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "unique ID, primary key for quote identification",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "customer_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "Foreign key referencing customers table",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "quote_number",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "unique reference number for the quote",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "total_premium",
#         "type": "Decimal",
#         "nullable": false,
#         "metadata": {
#           "description": "total premium amount for the quote",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Numeric"
#         }
#       },
#       {
#         "name": "effective_date",
#         "type": "Date",
#         "nullable": true,
#         "metadata": {
#           "description": "proposed start date for the insurance policy",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "expiration_date",
#         "type": "Date",
#         "nullable": true,
#         "metadata": {
#           "description": "proposed end date for the insurance policy",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "status",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "Status of the quote (draft, submitted, accepted, declined). Indicates the current state of the insurance quote in the sales process.",
#           "unique_fl": false,
#           "column_values": [
#             "draft",
#             "submitted",
#             "accepted",
#             "declined"
#           ],
#           "col_type": "Categorical"
#         }
#       },
#       {
#         "name": "created_at",
#         "type": "Timestamp",
#         "nullable": false,
#         "metadata": {
#           "description": "timestamp when quote was created",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "updated_at",
#         "type": "Timestamp",
#         "nullable": true,
#         "metadata": {
#           "description": "timestamp when quote was last updated",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       }
#     ]
#   },
#   "quote_coverages": {
#     "purpose": "Junction table linking quotes to selected coverage options with specific details",
#     "fields": [
#       {
#         "name": "quote_coverage_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "unique ID, primary key for quote coverage relationship",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "quote_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "Foreign key referencing quotes table",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "coverage_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "Foreign key referencing coverage_options table",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "vehicle_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "Foreign key referencing vehicles table",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "coverage_limit",
#         "type": "String",
#         "nullable": true,
#         "metadata": {
#           "description": "selected limit for this coverage",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Numeric"
#         }
#       },
#       {
#         "name": "deductible",
#         "type": "Decimal",
#         "nullable": true,
#         "metadata": {
#           "description": "selected deductible amount for this coverage",
#           "col_type": "Numeric"
#         }
#       },
#       {
#         "name": "premium",
#         "type": "Decimal",
#         "nullable": true,
#         "metadata": {
#           "description": "premium amount for this specific coverage",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Numeric"
#         }
#       },
#       {
#         "name": "created_at",
#         "type": "Timestamp",
#         "nullable": false,
#         "metadata": {
#           "description": "timestamp when quote coverage record was created",
#           "unique_fl": false,
#           "default_value": "CURRENT_TIMESTAMP",
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "updated_at",
#         "type": "Timestamp",
#         "nullable": true,
#         "metadata": {
#           "description": "timestamp when quote coverage record was last updated",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       }
#     ]
#   },
#   "discount_types": {
#     "purpose": "Stores types of discounts available for insurance quotes",
#     "fields": [
#       {
#         "name": "discount_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "unique ID, primary key for discount type identification",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "discount_name",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "Name of the discount (multi-car, good student, etc.) available for insurance quotes",
#           "unique_fl": "True",
#           "column_values": [
#             "multi-car",
#             "good student",
#             "safe driver",
#             "homeowner",
#             "loyalty",
#             "paperless",
#             "automatic payment",
#             "senior",
#             "military",
#             "professional"
#           ],
#           "col_type": "Categorical"
#         }
#       },
#       {
#         "name": "description",
#         "type": "String",
#         "nullable": false,
#         "metadata": {
#           "description": "detailed description of the discount",
#           "col_type": "Text"
#         }
#       },
#       {
#         "name": "discount_percentage",
#         "type": "Float",
#         "nullable": false,
#         "metadata": {
#           "description": "standard percentage value of the discount",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Numeric"
#         }
#       },
#       {
#         "name": "is_active",
#         "type": "Boolean",
#         "nullable": false,
#         "metadata": {
#           "description": "boolean indicating if this discount is currently offered",
#           "unique_fl": false,
#           "default_value": false,
#           "col_type": "Boolean"
#         }
#       },
#       {
#         "name": "created_at",
#         "type": "Timestamp",
#         "nullable": false,
#         "metadata": {
#           "description": "timestamp when discount type was created",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "updated_at",
#         "type": "Timestamp",
#         "nullable": false,
#         "metadata": {
#           "description": "timestamp when discount type was last updated",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Date"
#         }
#       }
#     ]
#   },
#   "quote_discounts": {
#     "purpose": "Junction table linking quotes to applied discounts",
#     "fields": [
#       {
#         "name": "quote_discount_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "unique ID, primary key for quote discount relationship",
#           "unique_fl": true,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "quote_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "foreign key referencing quotes table",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "discount_id",
#         "type": "Integer",
#         "nullable": false,
#         "metadata": {
#           "description": "Foreign key referencing discount_types table",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Unique_Identifier"
#         }
#       },
#       {
#         "name": "discount_amount",
#         "type": "Decimal",
#         "nullable": false,
#         "metadata": {
#           "description": "actual amount or percentage applied for this quote",
#           "unique_fl": false,
#           "default_value": null,
#           "col_type": "Numeric"
#         }
#       },
#       {
#         "name": "created_at",
#         "type": "Timestamp",
#         "nullable": false,
#         "metadata": {
#           "description": "timestamp when quote discount record was created",
#           "unique_fl": false,
#           "default_value": "CURRENT_TIMESTAMP",
#           "col_type": "Date"
#         }
#       },
#       {
#         "name": "updated_at",
#         "type": "Timestamp",
#         "nullable": true,
#         "metadata": {
#           "description": "timestamp when quote discount record was last updated",
#           "col_type": "Date"
#         }
#       }
#     ]
#   }
# }

# %%
# export the schema to a JSON file
import json

output_file_path = os.path.join(notebook_path, 'output_schema_kafka.json')
with open(output_file_path, 'w') as output_file:
    json.dump(test_schema_refiner.output_params, output_file, indent=2)
print(f"Schema exported to {output_file_path}")
# Out:
# Schema exported to c:\Users\dalej\Documents\_Coding\DragonRegen\docs\AIGuardian\output_schema.json
